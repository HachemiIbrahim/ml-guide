# %%
import pandas as pd

# %%
# series is 1-dimension

# %%
cars = pd.Series(["T1" , "T2" , "T3"])
cars
# Out:
# 0    T1
# 1    T2
# 2    T3
# dtype: object

# %%
colors = pd.Series(["Red" , "Blue" , "Green"])
colors
# Out:
# 0      Red
# 1     Blue
# 2    Green
# dtype: object

# %%
# dataFrame is 2-dimension
car_frame = pd.DataFrame({"maker" : cars , "colors" : colors})
car_frame
# Out:
#   maker colors
# 0    T1    Red
# 1    T2   Blue
# 2    T3  Green

# %%
# create a dataFrame from CSV
cars = pd. read_csv("car-sales.csv")
cars
# axis 0 = row
# axis 1 = column
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# exporting dataFrame to csv
# index = False so it don't create a index column
cars.to_csv("exported_cars" , index = False)

# %% [markdown]
# ## Describing Data

# %%
cars.dtypes
# types of cars dataframe
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
cars.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %% [markdown]
# ## Selecting and Viwing data

# %%
# Select row at index 3
cars.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Select row at position 3
cars.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
cars["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
cars.plot(x="Make", y="Odometer (KM)");

# %%
cars["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
cars
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
cars["Price"] = cars["Price"].str.replace("[\$\,\.]" , "" , regex=True).astype(int)

# %%
cars
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
cars["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating data

# %%
cars["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
cars["Make"] = cars["Make"].str.lower()

# %%
cars
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
cars_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
cars_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# inplace = True to write the nan values in odemeter with 0
cars_missing["Odometer"].fillna(0 , inplace=True)

# %%
cars_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       0.0    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       0.0    4.0   $4,500
# 6   Honda    NaN       0.0    4.0   $7,500
# 7   Honda   Blue       0.0    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# inplace = True to drop rows with nan values
cars_missing.dropna(inplace = True)

# %%
cars_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       0.0    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       0.0    4.0   $4,500

# %%
# Create a column from a Python list
engine_sizes = [1.3, 2.0, 3.0, 4.2, 1.6, 1, 2.0, 2.3, 2.0, 3.0]
cars["Engine Size"] = engine_sizes
cars
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Engine Size
# 0  toyota  White         150043      4   400000          1.3
# 1   honda    Red          87899      4   500000          2.0
# 2  toyota   Blue          32549      3   700000          3.0
# 3     bmw  Black          11179      5  2200000          4.2
# 4  nissan  White         213095      4   350000          1.6
# 5  toyota  Green          99213      4   450000          1.0
# 6   honda   Blue          45698      4   750000          2.0
# 7   honda   Blue          54738      4   700000          2.3
# 8  toyota  White          60000      4   625000          2.0
# 9  nissan  White          31600      4   970000          3.0

# %%
cars["Number of wheels"] = 4
cars
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Engine Size  Number of wheels
# 0  toyota  White         150043      4   400000          1.3                 4
# 1   honda    Red          87899      4   500000          2.0                 4
# 2  toyota   Blue          32549      3   700000          3.0                 4
# 3     bmw  Black          11179      5  2200000          4.2                 4
# 4  nissan  White         213095      4   350000          1.6                 4
# 5  toyota  Green          99213      4   450000          1.0                 4
# 6   honda   Blue          45698      4   750000          2.0                 4
# 7   honda   Blue          54738      4   700000          2.3                 4
# 8  toyota  White          60000      4   625000          2.0                 4
# 9  nissan  White          31600      4   970000          3.0                 4

# %%
cars = cars.drop("Number of wheels" , axis = 1)

# %%
cars
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Engine Size
# 0  toyota  White         150043      4   400000          1.3
# 1   honda    Red          87899      4   500000          2.0
# 2  toyota   Blue          32549      3   700000          3.0
# 3     bmw  Black          11179      5  2200000          4.2
# 4  nissan  White         213095      4   350000          1.6
# 5  toyota  Green          99213      4   450000          1.0
# 6   honda   Blue          45698      4   750000          2.0
# 7   honda   Blue          54738      4   700000          2.3
# 8  toyota  White          60000      4   625000          2.0
# 9  nissan  White          31600      4   970000          3.0
